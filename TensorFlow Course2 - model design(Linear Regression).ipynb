# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### random linear data generation

# %% [markdown]
# - x1: 0.0 ~ 0.55 사이의 랜덤 데이터
# - y1: 0.1*x1 + 0.3 + 가우시안 분포(정규 분포)에 따른 편차

# %%
import numpy as np

num_points = 1000
vectors_set = []
for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

# %% [markdown]
# - 데이터 플롯

# %%
import matplotlib.pyplot as plt

#Graphic display
plt.plot(x_data, y_data, 'ro')
plt.legend()
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# - Tensorflow import

# %%
import tensorflow as tf

# %% [markdown]
# - linear regression 식
# - Wx + b

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# %% [markdown]
# - regression 오차 함수 : 제곱 오차(squared error)

# %%
loss = tf.reduce_mean(tf.square(y - y_data))

# %% [markdown]
# - Learning rate : 0.5
# - GradientDesent 적용

# %%
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

# %%
for step in range(8):
    sess.run(train)
    print(step, sess.run(W), sess.run(b))
    print(step, sess.run(loss))
    
    #Graphic display
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    plt.xlabel('x')
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6)
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# 0 [-0.11382466] [ 0.29747102]
# 0 0.0146986
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# 1 [-0.05045697] [ 0.29799163]
# 1 0.0078393
# 2 [-0.00558579] [ 0.29837096]
# 2 0.00439991
# 3 [ 0.02618793] [ 0.29863957]
# 3 0.00267533
# 4 [ 0.0486872] [ 0.29882976]
# 4 0.00181059
# 5 [ 0.06461916] [ 0.29896444]
# 5 0.001377
# 6 [ 0.07590073] [ 0.29905981]
# 6 0.00115959
# 7 [ 0.08388933] [ 0.29912734]
# 7 0.00105057

# %% [markdown]
# ### Result

# %%
plt.plot(x_data, y_data, 'ro')
plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
plt.legend()
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
